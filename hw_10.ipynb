# %%
import pandas as pd

# %%
# задание 1

dataset = pd.read_csv('ratings.csv')
dataset.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
new_dataset = dataset.query('rating == 5.0')
new_dataset
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 8              1     1237     5.0  1147868839
# 18             1     2632     5.0  1147878248
# ...          ...      ...     ...         ...
# 25000065  162541     5952     5.0  1240952617
# 25000067  162541     6104     5.0  1240953565
# 25000078  162541     7153     5.0  1240952613
# 25000080  162541     7193     5.0  1240950032
# 25000094  162541    63876     5.0  1240952515
#
# [3612474 rows x 4 columns]

# %%
#посчитаем количество строк, приходящихся на каждый movieId, по убыванию, первым будет movieId с максимальным кол-м оценки 5.0
new_dataset['movieId'].value_counts().sort_values(ascending=False).head()
# Out:
# 318     39553
# 296     32169
# 356     25918
# 260     25804
# 2571    25482
# Name: movieId, dtype: int64

# %%
pd.read_csv('movies.csv')
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
data.query('movieId == 318')
# Out:
#      movieId                             title       genres
# 314      318  Shawshank Redemption, The (1994)  Crime|Drama

# %%
# задание 2

data = pd.read_csv('power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
new_data = data[ (data['country']=='Latvia') | (data['country']=='Litva') | (data['country']=='Estonia')]

# %%
new_data_2 = new_data[ (new_data['year']==2005) | (new_data['year']==2006) | (new_data['year']==2007) | (new_data['year']==2008) | (new_data['year']==2009) | (new_data['year']==2010)]

# %%
new_data_3 = new_data_2 [ (new_data_2['category']==4) | (new_data_2['category']==12) | (new_data_2['category']==21) ]
new_data_3
# Out:
#         country  year  quantity  category
# 10617   Estonia  2008       1.0         4
# 10618   Estonia  2007       0.0         4
# 10619   Estonia  2006       0.0         4
# 10620   Estonia  2005       1.0         4
# 12755   Estonia  2008       1.0         4
# ...         ...   ...       ...       ...
# 253963   Latvia  2009      32.0        21
# 253964   Latvia  2008      28.0        21
# 253965   Latvia  2007      26.0        21
# 253966   Latvia  2006      27.0        21
# 253967   Latvia  2005      27.0        21
#
# [191 rows x 4 columns]

# %%
new_data_3.quantity.sum()
# Out:
# 118284.0

# %%
#задание 3

pd.read_html('https://fortrader.org/quotes')[1]
# Out:
#                                     Type          Last       Chg.      Chg.%  \
# 0                          ВТБ Акции ВТБ       0.04646  +0.000270   0.584542
# 1                 Газпром Акции газпрома     226.60000      -1.43  -0.630000
# 2                    Лукойл Акции Лукойл    6561.00000      -11.0  -0.200000
# 3                Роснефть Акции Роснефти     479.80000      -1.05  -0.220000
# 4               Сбербанк Акции Сбербанка     252.40000      -2.05  -0.810000
# 5   Сургутнефтегаз Акции Сургутнефтегаза      46.22500     +1.715   3.853000
# 6              Норникель Акции Норникель   20766.00000       +333   2.000000
# 7               Аэрофлот Акции Аерофлота     107.44000      -2.36  -2.150000
# 8            Северсталь Акции Северсталь     913.80000      +6.80   0.750000
# 9            Транснефть Акции транснефти  164950.00000     -1 350  -1.000000
# 10     Ростелеком Курс акций ростелекома      88.05000     +15.22  20.900000
# ...

# %%
pd.read_html('https://fortrader.org/quotes')[2]
# Out:
#                           Type      Last      Chg.   Chg.%  Time
# 0      Серебро Цена на серебро    17.578   -0.0750 -0.4250   NaN
# 1    Палладий Цена на Палладий  2329.250  100.7000  4.5200   NaN
# 2  Золото Цена золота на бирже  1551.640  -24.9700 -1.5800   NaN
# 3      Платина Цены на платину   965.200   -4.2000 -0.4000   NaN
# 4      Медь Цена меди на бирже     2.541    0.0355  1.4169   NaN

# %%
page_url = 'https://fortrader.org/quotes'
df = pd.read_html(page_url, encoding='utf-8')

# %%
df[:5]
# Out:
# [                               Type    Last   Chg.  Chg.%  Time
#  0  Нефть (BRENT) Курс нефти сегодня  54.450  0.680  1.260   NaN
#  1   Нефть (WTI) Цены на нефть (WTI)  49.980  0.620  1.260   NaN
#  2          Сахар котировки на сахар  12.630  0.000  0.000   NaN
#  3                   Газ Цена на газ   1.871 -0.004 -0.213   NaN,
#                                      Type          Last       Chg.      Chg.%  \
#  0                          ВТБ Акции ВТБ       0.04646  -0.000470  -1.001492
#  1                 Газпром Акции газпрома     226.60000      -4.18  -1.810000
#  2                    Лукойл Акции Лукойл    6561.00000      +67.0   1.000000
#  3                Роснефть Акции Роснефти     479.80000      -0.80  -0.170000
#  4               Сбербанк Акции Сбербанка     252.40000      -3.21  -1.260000
#  5   Сургутнефтегаз Акции Сургутнефтегаза      46.22500     -0.485  -1.038000
#  6              Норникель Акции Норникель   20766.00000       -142  -1.000000
# ...
